# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/cement_slump.csv")

# %%
df.head()
# Out:
#    Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 0   273.0   82.0    105.0  210.0   9.0         904.0       680.0       23.0
# 1   163.0  149.0    191.0  180.0  12.0         843.0       746.0        0.0
# 2   162.0  148.0    191.0  179.0  16.0         840.0       743.0        1.0
# 3   162.0  148.0    190.0  179.0  19.0         838.0       741.0        3.0
# 4   154.0  112.0    144.0  220.0  10.0         923.0       658.0       20.0
#
#    FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0      62.0                               34.99
# 1      20.0                               41.14
# 2      20.0                               41.81
# 3      21.5                               42.08
# 4      64.0                               26.82

# %%
df.columns
# Out:
# Index(['Cement', 'Slag', 'Fly ash', 'Water', 'SP', 'Coarse Aggr.',
#        'Fine Aggr.', 'SLUMP(cm)', 'FLOW(cm)',
#        'Compressive Strength (28-day)(Mpa)'],
#       dtype='object')

# %%
df.columns = ['Cement', 'Slag', 'Fly ash', 'Water', 'SP', 'Coarse Aggr.',
       'Fine Aggr.', 'SLUMP(cm)', 'FLOW(cm)',
       'Compressive Strength']

# %%
df
# Out:
#      Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 0     273.0   82.0    105.0  210.0   9.0         904.0       680.0       23.0
# 1     163.0  149.0    191.0  180.0  12.0         843.0       746.0        0.0
# 2     162.0  148.0    191.0  179.0  16.0         840.0       743.0        1.0
# 3     162.0  148.0    190.0  179.0  19.0         838.0       741.0        3.0
# 4     154.0  112.0    144.0  220.0  10.0         923.0       658.0       20.0
# ..      ...    ...      ...    ...   ...           ...         ...        ...
# 98    248.3  101.0    239.1  168.9   7.7         954.2       640.6        0.0
# 99    248.0  101.0    239.9  169.1   7.7         949.9       644.1        2.0
# 100   258.8   88.0    239.6  175.3   7.6         938.9       646.0        0.0
# 101   297.1   40.9    239.9  194.0   7.5         908.9       651.8       27.5
# 102   348.7    0.1    223.1  208.5   9.6         786.2       758.1       29.0
#
#      FLOW(cm)  Compressive Strength
# 0        62.0                 34.99
# 1        20.0                 41.14
# 2        20.0                 41.81
# 3        21.5                 42.08
# 4        64.0                 26.82
# ..        ...                   ...
# 98       20.0                 49.97
# 99       20.0                 50.23
# 100      20.0                 50.50
# 101      67.0                 49.17
# 102      78.0                 48.70
#
# [103 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# Cement                  0
# Slag                    0
# Fly ash                 0
# Water                   0
# SP                      0
# Coarse Aggr.            0
# Fine Aggr.              0
# SLUMP(cm)               0
# FLOW(cm)                0
# Compressive Strength    0
# dtype: int64

# %%
X = df.drop(columns = 'Compressive Strength', axis = 0)

# %%
y = df['Compressive Strength']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
preds = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test, preds))
# Out:
# 4.095067817903113

# %%
#create pickle file

# %%
import pickle
pickle_out = open("rf.pkl","wb")
pickle.dump(model, pickle_out)
pickle_out.close()

# %%
X_test
# Out:
#     Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 37   165.0  150.0      0.0  182.0  12.0        1023.0       729.0      14.50
# 1    163.0  149.0    191.0  180.0  12.0         843.0       746.0       0.00
# 69   336.0  134.0      0.0  222.0   6.0         756.0       787.0      26.00
# 80   140.1    4.2    215.9  193.9   4.7        1049.5       710.1      24.50
# 92   303.8    0.2    239.8  236.4   8.3         780.1       715.3      25.00
# 61   288.0    0.0    121.0  177.0   7.0         908.0       829.0      22.50
# 85   140.5   61.1    238.9  182.5   5.7        1017.7       681.4      24.50
# 53   309.0    0.0    142.0  218.0  10.0         912.0       680.0      24.00
# 88   150.4  110.9    239.7  168.1   6.5        1000.2       667.2       9.50
# 32   366.0    0.0    187.0  191.0   7.0         824.0       757.0      24.75
# 6    152.0  139.0    178.0  168.0  18.0         944.0       695.0       0.00
# 71   313.0  112.0      0.0  220.0  10.0         794.0       789.0      23.00
# 43   291.0  105.0      0.0  205.0   6.0         859.0       797.0      24.00
# 16   153.0    0.0    239.0  200.0   6.0        1002.0       684.0      12.00
# 50   320.0    0.0    163.0  188.0   9.0         866.0       776.0      23.50
# 31   349.0    0.0    178.0  230.0   6.0         785.0       721.0      20.00
# 97   295.3    0.0    239.9  236.2   8.3         780.3       722.9      25.00
# 14   374.0    0.0      0.0  190.0   7.0        1013.0       730.0      14.50
# 25   140.0  128.0    164.0  183.0  12.0         871.0       775.0      23.75
# 51   342.0  136.0      0.0  225.0  11.0         770.0       747.0      21.00
# 21   310.0    0.0    143.0  218.0  10.0         787.0       804.0      13.00
# 3    162.0  148.0    190.0  179.0  19.0         838.0       741.0       3.00
# 84   140.2   44.8    234.9  171.3   5.5        1047.6       704.0      23.50
# 57   313.0  124.0      0.0  205.0  11.0         846.0       758.0      22.00
# 48   332.0    0.0    170.0  160.0   6.0         900.0       806.0       0.00
# 47   287.0   94.0    121.0  188.0   9.0         904.0       696.0      25.00
# 79   141.1    0.6    209.5  188.8   4.6         996.1       789.2      23.50
# 58   143.0  131.0    168.0  217.0   6.0         891.0       672.0      25.00
# 2    162.0  148.0    191.0  179.0  16.0         840.0       743.0       1.00
# 13   354.0    0.0      0.0  234.0   6.0         959.0       691.0      17.00
# 45   318.0  126.0      0.0  210.0   6.0         861.0       737.0      17.50
#
#     FLOW(cm)
# 37      20.0
# 1       20.0
# 69      64.0
# 80      57.0
# 92      78.0
# 61      48.5
# 85      60.0
# 53      62.0
# 88      27.5
# 32      62.7
# 6       20.0
# 71      58.0
# 43      59.0
# 16      35.0
# 50      60.0
# 31      68.5
# 97      77.0
# 14      42.5
# 25      53.0
# 51      61.0
# 21      46.0
# 3       21.5
# 84      52.5
# 57      49.0
# 48      20.0
# 47      61.0
# 79      53.0
# 58      69.0
# 2       20.0
# 13      54.0
# 45      48.0
